# %%
name = input("Enter your full name ")
age = input("Enter your age :")
city = input ("Enter your city:")

print(f"My name is {name } . I am {age } years old . I live in {city}")
# Out:
# My name is 10 . I am 10 years old . I live in 10

# %%
total_data_used = float(input("Enter total data used in your mobile (GB)"))
price = float(input("Enter price per GB:"))
total_price = round((total_data_used * price) , 2)
price_per_mb = round((total_price / 1024) , 2)
next_month_usage = round((total_data_used * 1.2 ) , 2)

print(f"Total Bill : $ {total_price}")
print(f"Average Cost per MB: $ {price_per_mb}")
print(f"Projected cost = $ { round((next_month_usage * price), 2)} for {next_month_usage} GB")
# Out:
# Total Bill : $ 160.8
# Average Cost per MB: $ 0.16
# Projected cost = $ 192.96 for 14.4 GB

# %%
password = input("Enter you password")
special_char = [ '%' , '@' , '&' , '#' , '!' , '^' , '*' , '(' ,'_' , '-']
def has_upper(string):
    for char in string:
        if char.isupper():
            return True
    return False
def has_num(string):
    for char in string:
        if char.isdigit():
            return True
    return False
def check_password(password):
    errors = []
    if len(password)<8:
        errors.append("Length less than 8")
    if not has_num(password):
        errors.append("No Numbers")
    if  not has_upper(password):
        errors.append("No upper case latters")
    if not any( c in password for c in special_char):
        errors.append("No special characters")
    return errors

errors = check_password(password)

if not errors:
    print("strong password")
else:
    print(f"Weak Password {errors}")
# Out:
# Weak Password ['No special characters']

# %%
def has_num(string):
    for char in string:
        if char.isdigit():
            return True
    return False
print(not has_num("sjdhf1s"))
# "attention is all you need"
# Out:
# False
